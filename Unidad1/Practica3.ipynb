# %% [markdown]
# <a href="https://colab.research.google.com/github/wingchicken1225-del/Probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Probabilidad y Estadistica**
#
# ## Unidad 1
#
# ## **Practica 3: Tabla de Frecuencias y Regla de Sturges**
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas
#
# Alumno: Jesus Antonio Soto

# %%
# basado en el LIBRO estadistica para administracion pagina 12
# creamos una lista vacia que representa la edad de 100 personas
import random
import matplotlib.pyplot as plt #Libreria para graficar

edades = []

# Hacemos un ciclo para generar 100 numeros aleatorios qe representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
    # numero_aleatorio
    numero_aleatorio = random.randint(18, 70)

    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)

print(edades)
# Out:
# [67, 24, 42, 40, 61, 54, 38, 47, 45, 19, 47, 56, 58, 62, 50, 40, 49, 31, 37, 62, 29, 36, 24, 36, 54, 27, 62, 65, 33, 34, 63, 20, 60, 53, 44, 37, 53, 58, 53, 55, 20, 34, 65, 42, 58, 50, 39, 38, 41, 48, 24, 22, 47, 69, 18, 39, 53, 61, 26, 69, 28, 44, 43, 21, 66, 22, 36, 53, 64, 48, 32, 61, 32, 26, 21, 43, 67, 44, 69, 50, 70, 33, 42, 54, 48, 47, 25, 37, 34, 59, 24, 25, 43, 57, 49, 31, 48, 36, 42, 43]

# %%
import pandas as pd

# %%
# Crear un DataFrame de pandas con los números aleatorios

df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    67
# 1    24
# 2    42
# 3    40
# 4    61

# %%
# Calcular la tabla de distribución de frecuencias

tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 39    18           1
# 31    19           1
# 23    20           2
# 20    21           2
# 26    22           2
# 1     24           4
# 17    25           2
# 25    26           2
# 37    27           1
# 38    28           1
# 34    29           1
# 28    31           2
# 16    32           2
# 27    33           2
# 14    34           3
# 4     36           4
# 15    37           3
# 21    38           2
# 22    39           2
# 19    40           2
# 40    41           1
# 5     42           4
# 3     43           4
# 9     44           3
# 32    45           1
# 2     47           4
# 6     48           4
# 29    49           2
# 12    50           3
# 0     53           5
# 11    54           3
# 33    55           1
# 30    56           1
# 45    57           1
# 7     58           3
# 44    59           1
# 35    60           1
# 13    61           3
# 10    62           3
# 36    63           1
# 42    64           1
# 24    65           2
# 41    66           1
# 18    67           2
# 8     69           3
# 43    70           1

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 39    18           1           0.01
# 31    19           1           0.01
# 23    20           2           0.02
# 20    21           2           0.02
# 26    22           2           0.02
# 1     24           4           0.04
# 17    25           2           0.02
# 25    26           2           0.02
# 37    27           1           0.01
# 38    28           1           0.01
# 34    29           1           0.01
# 28    31           2           0.02
# 16    32           2           0.02
# 27    33           2           0.02
# 14    34           3           0.03
# 4     36           4           0.04
# 15    37           3           0.03
# 21    38           2           0.02
# 22    39           2           0.02
# 19    40           2           0.02
# 40    41           1           0.01
# 5     42           4           0.04
# 3     43           4           0.04
# 9     44           3           0.03
# 32    45           1           0.01
# 2     47           4           0.04
# 6     48           4           0.04
# 29    49           2           0.02
# 12    50           3           0.03
# 0     53           5           0.05
# 11    54           3           0.03
# 33    55           1           0.01
# 30    56           1           0.01
# 45    57           1           0.01
# 7     58           3           0.03
# 44    59           1           0.01
# 35    60           1           0.01
# 13    61           3           0.03
# 10    62           3           0.03
# 36    63           1           0.01
# 42    64           1           0.01
# 24    65           2           0.02
# 41    66           1           0.01
# 18    67           2           0.02
# 8     69           3           0.03
# 43    70           1           0.01

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 39    18           1           0.01              1.0
# 31    19           1           0.01              1.0
# 23    20           2           0.02              2.0
# 20    21           2           0.02              2.0
# 26    22           2           0.02              2.0
# 1     24           4           0.04              4.0
# 17    25           2           0.02              2.0
# 25    26           2           0.02              2.0
# 37    27           1           0.01              1.0
# 38    28           1           0.01              1.0
# 34    29           1           0.01              1.0
# 28    31           2           0.02              2.0
# 16    32           2           0.02              2.0
# 27    33           2           0.02              2.0
# 14    34           3           0.03              3.0
# 4     36           4           0.04              4.0
# 15    37           3           0.03              3.0
# 21    38           2           0.02              2.0
# 22    39           2           0.02              2.0
# 19    40           2           0.02              2.0
# 40    41           1           0.01              1.0
# 5     42           4           0.04              4.0
# 3     43           4           0.04              4.0
# 9     44           3           0.03              3.0
# 32    45           1           0.01              1.0
# 2     47           4           0.04              4.0
# 6     48           4           0.04              4.0
# 29    49           2           0.02              2.0
# 12    50           3           0.03              3.0
# 0     53           5           0.05              5.0
# 11    54           3           0.03              3.0
# 33    55           1           0.01              1.0
# 30    56           1           0.01              1.0
# 45    57           1           0.01              1.0
# 7     58           3           0.03              3.0
# 44    59           1           0.01              1.0
# 35    60           1           0.01              1.0
# 13    61           3           0.03              3.0
# 10    62           3           0.03              3.0
# 36    63           1           0.01              1.0
# 42    64           1           0.01              1.0
# 24    65           2           0.02              2.0
# 41    66           1           0.01              1.0
# 18    67           2           0.02              2.0
# 8     69           3           0.03              3.0
# 43    70           1           0.01              1.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 39    18           1           0.01              1.0               1
# 31    19           1           0.01              1.0               2
# 23    20           2           0.02              2.0               4
# 20    21           2           0.02              2.0               6
# 26    22           2           0.02              2.0               8
# 1     24           4           0.04              4.0              12
# 17    25           2           0.02              2.0              14
# 25    26           2           0.02              2.0              16
# 37    27           1           0.01              1.0              17
# 38    28           1           0.01              1.0              18
# 34    29           1           0.01              1.0              19
# 28    31           2           0.02              2.0              21
# 16    32           2           0.02              2.0              23
# 27    33           2           0.02              2.0              25
# 14    34           3           0.03              3.0              28
# 4     36           4           0.04              4.0              32
# 15    37           3           0.03              3.0              35
# 21    38           2           0.02              2.0              37
# 22    39           2           0.02              2.0              39
# 19    40           2           0.02              2.0              41
# 40    41           1           0.01              1.0              42
# 5     42           4           0.04              4.0              46
# 3     43           4           0.04              4.0              50
# 9     44           3           0.03              3.0              53
# 32    45           1           0.01              1.0              54
# 2     47           4           0.04              4.0              58
# 6     48           4           0.04              4.0              62
# 29    49           2           0.02              2.0              64
# 12    50           3           0.03              3.0              67
# 0     53           5           0.05              5.0              72
# 11    54           3           0.03              3.0              75
# 33    55           1           0.01              1.0              76
# 30    56           1           0.01              1.0              77
# 45    57           1           0.01              1.0              78
# 7     58           3           0.03              3.0              81
# 44    59           1           0.01              1.0              82
# 35    60           1           0.01              1.0              83
# 13    61           3           0.03              3.0              86
# 10    62           3           0.03              3.0              89
# 36    63           1           0.01              1.0              90
# 42    64           1           0.01              1.0              91
# 24    65           2           0.02              2.0              93
# 41    66           1           0.01              1.0              94
# 18    67           2           0.02              2.0              96
# 8     69           3           0.03              3.0              99
# 43    70           1           0.01              1.0             100

# %% [markdown]
# #**Regla de Sturges**
# ##Es una regla que sirve para calcular el número de clases o intervalos idóneo en los que se debe dividir un conjunto de datos.
# ##Establece que el número de clases es igual a uno más el logaritmo en base dos del número total de datos.
#
# c = 1 + log₂(N)
#
# donde N es el tamaño de la muestra.

# %%
# Importamos la librería math de funciones matemáticas
import math

# %%
# Volvemos a usar la lista edades
print(edades)
# Out:
# [67, 24, 42, 40, 61, 54, 38, 47, 45, 19, 47, 56, 58, 62, 50, 40, 49, 31, 37, 62, 29, 36, 24, 36, 54, 27, 62, 65, 33, 34, 63, 20, 60, 53, 44, 37, 53, 58, 53, 55, 20, 34, 65, 42, 58, 50, 39, 38, 41, 48, 24, 22, 47, 69, 18, 39, 53, 61, 26, 69, 28, 44, 43, 21, 66, 22, 36, 53, 64, 48, 32, 61, 32, 26, 21, 43, 67, 44, 69, 50, 70, 33, 42, 54, 48, 47, 25, 37, 34, 59, 24, 25, 43, 57, 49, 31, 48, 36, 42, 43]

# %%
# Crear un DataFrame con las edades

df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     67
# 1     24
# 2     42
# 3     40
# 4     61
# ..   ...
# 95    31
# 96    48
# 97    36
# 98    42
# 99    43
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges

n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n = ", n, "\nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (32.857, 40.286]    18
# 1  (47.714, 55.143]    18
# 2  (40.286, 47.714]    17
# 3  (17.947, 25.429]    14
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    11
# 6  (25.429, 32.857]     9

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 3  (17.947, 25.429]    14
# 6  (25.429, 32.857]     9
# 0  (32.857, 40.286]    18
# 2  (40.286, 47.714]    17
# 1  (47.714, 55.143]    18
# 4  (55.143, 62.571]    13
# 5    (62.571, 70.0]    11

# %%
# Generar columnas siguientes

tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 3  (17.947, 25.429]    14      0.14       14.0       14         0.14
# 6  (25.429, 32.857]     9      0.09        9.0       23         0.23
# 0  (32.857, 40.286]    18      0.18       18.0       41         0.41
# 2  (40.286, 47.714]    17      0.17       17.0       58         0.58
# 1  (47.714, 55.143]    18      0.18       18.0       76         0.76
# 4  (55.143, 62.571]    13      0.13       13.0       89         0.89
# 5    (62.571, 70.0]    11      0.11       11.0      100         1.00
#
#    Frec Porc Ac
# 3          14.0
# 6          23.0
# 0          41.0
# 2          58.0
# 1          76.0
# 4          89.0
# 5         100.0

# %%
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia

plt.hist(df["Edad"], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
